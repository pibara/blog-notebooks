# %%
# %matplotlib inline
import math
import numpy as np
import pandas
import matplotlib.pyplot as plt

# Import the relevant CSF files from https://fineli.fi/fineli/fi/avoin-data.
# These files are part of the 1.5MB zip file download option on the Fineli website.
#
component_value = pandas.read_csv("component_value.csv", sep=';', decimal=',')
food =  pandas.read_csv("food.csv", sep=';', encoding='latin1')
foodname = pandas.read_csv("foodname_EN.csv", sep=';', encoding='latin1')
fuclass = pandas.read_csv("fuclass_EN.csv", sep=';')
eufdname = pandas.read_csv("eufdname_EN.csv", sep=';')
# Some patching for the component value data
component_value = component_value[component_value['EUFDNAME'].apply(lambda x: isinstance(x, (str)))]

# %%
#The second big step is creating the new data frame that should end up containing
# a list of normalized vector representation of the nutritional values for each food.
#
# We start off with two merges to combine the base info from food, food class and food name csv files.
df = pandas.merge(left=food[["FOODID","FUCLASS"]], right=fuclass[["THSCODE", "DESCRIPT"]], \
                  how='left', left_on="FUCLASS", right_on="THSCODE")[["FOODID","DESCRIPT"]]
foodshort = foodname[["FOODID","FOODNAME"]]
df = pandas.merge(how='left', right=df, left=foodshort, left_on="FOODID", right_on="FOODID")

#Now we itterate each of the unique component names in the component value CSV file.
for comp in component_value["EUFDNAME"].unique():
    # Take a filtered version of nutrient values for different foods for just one component name.
    filtered = component_value[component_value["EUFDNAME"] == comp][["FOODID","BESTLOC"]]
    #Calculate the mean value and standard deviation for the named component across all foods.
    std = filtered.loc[:,"BESTLOC"].std(axis=0)
    mean = filtered.loc[:,"BESTLOC"].mean(axis=0)
    # Normalize the component values for the named component.
    filtered[comp] = (filtered["BESTLOC"] - mean) / std
    # Merge the normalized component values into our dataframe
    filtered = filtered[["FOODID", comp]]
    df = pandas.merge(left=df,right=filtered, how='left', left_on='FOODID', right_on='FOODID')
#Replace all NotANumber values with a zero.
df = df.fillna(0)

# %%
#We shall use the vector distance between the mean vector for all fruit and the mean
# vector for all veggies as reference vector distance for looking at food group.
fruit = df.loc[df['DESCRIPT'] == 'Fruits']
vegies = df.loc[df['DESCRIPT'] == 'Vegetables']
reference_vectordistance = np.linalg.norm((vegies.mean() - fruit.mean()).values[1:])

#Create a new list for our results.
rowlist = []

#Itterate over all food groups defined in this data set, except for fruits.
for foodtype in df["DESCRIPT"].unique():
    if foodtype != 'Fruits':
        # Calculate the vector distance between fruits and this food group.
        other = df.loc[df['DESCRIPT'] == foodtype]
        vectordistance = np.linalg.norm((other.mean() - fruit.mean()).values[1:])
        # If the vector distance is up to twice the vector distance between fruit and veggies,
        # add it to our results list.
        if vectordistance/reference_vectordistance < 2.0001:
            row = dict()
            row["foodtype"] = foodtype
            row["reldistance"] = vectordistance/reference_vectordistance
            rowlist.append(row)

# Turn the constructed row list into a pandas dataframe
peergroups = pandas.DataFrame(rowlist)

#Display the other food groups and their relative vecto distance from fruit.
# A value of 1.0 denotes the same vector distance as between fruits and veggies
with pandas.option_context('display.max_rows', None, 'display.max_columns', None):
    print(peergroups.sort_values(by=['reldistance']))
# Out:
#                                    foodtype  reldistance
# 71             Baby fruit and berry product     0.254584
# 12                                   Juices     0.324371
# 11                   Fruit and berry salads     0.419500
# 53                         Vegetable salads     0.433896
# 15                              Juice drink     0.499597
# 54                    Fruit and berry soups     0.512050
# 47   Fruit and berry dishes other than pies     0.572982
# 33                             Other drinks     0.619280
# 49                          Vegetable soups     0.652777
# 72                   Baby vegetable product     0.655973
# 31                    Soft drink with sugar     0.710715
# 9                          Vegetable juices     0.716880
# 60                              Pulse soups     0.729302
# 48                            Potato dishes     0.742103
# 51                        Cooked vegetables     0.744533
# 55                         Vegetable sauces     0.753597
# 52                         Vegetable dishes     0.764830
# 74                           Baby fish dish     0.774588
# 34                           Drinking water     0.778795
# 62                               Meat soups     0.780833
# 21                                  Yoghurt     0.805619
# 58                             Pulse sauces     0.806330
# 17                            Milks skimmed     0.809094
# 73                           Baby meat dish     0.825446
# 36                                 Porridge     0.829892
# 78                              Sport drink     0.831736
# 65                            Poultry soups     0.842000
# 20                           Cultured milks     0.845855
# 29                                   Coffee     0.846159
# 30                                      Tea     0.850300
# 4                           Cooked potatoes     0.889403
# 50                             Mixed salads     0.897260
# 59                             Pulse dishes     0.897811
# 16                            Milks >2% fat     0.907533
# 18                             Soured milks     0.912002
# 46                            Milk desserts     0.920313
# 23                            Milks <2% fat     0.928574
# 35        Drinks with artificial sweeteners     0.935823
# 77                             Seafood soup     0.936404
# 44                              Milk sauces     0.999358
# 6                                Vegetables     1.000000
# 22                                    Quark     1.000320
# 81                       Dietary supplement     1.013490
# 1                            Savoury sauces     1.037593
# 13                                  Berries     1.054466
# 68                               Fish soups     1.064546
# 5              Fried potatoes, French fries     1.106613
# 56          Prepared salads with mayonnaise     1.109879
# 43                                Panncakes     1.132018
# 66                           Poultry dishes     1.169911
# 8                           Mushroom dishes     1.174364
# 26                                Ice cream     1.194230
# 76  Seafood dishes, crustacean and molluscs     1.225429
# 61                              Meat sauces     1.226042
# 57                              Meat dishes     1.229997
# 70                           Dessert sauces     1.237735
# 19           Fermented milk products, other     1.259492
# 67                           Poultry sauces     1.285769
# 3                                      Rice     1.313129
# 24                                    Cream     1.329619
# 75                           Seafood sauces     1.334021
# 80                                    Pizza     1.337806
# 38                           Savoury bakery     1.343459
# 2                                     Pasta     1.345270
# 0                                Condiments     1.378994
# 40                   Sandwiches and burgers     1.403498
# 39                             Sweet bakery     1.447861
# 14                      Jams and marmalades     1.461037
# 32                                   Ciders     1.513203
# 69                              Fish sauces     1.523617
# 42                                     Buns     1.609077
# 45                               Egg dishes     1.611915
# 63                              Fish dishes     1.682396
# 41                              Wheat bread     1.689758
# 64                                 Sausages     1.708877
# 37                       Bread, mixed flour     1.730758
# 10                                   Pulses     1.739442
# 25          Cheese, unripened, fresh cheese     1.739644
# 7                         Canned vegetables     1.781269
# 79                      Cold cuts, sausages     1.807501
# 28                 Crustaceans and molluscs     1.904892
# 27                          Cold cuts, meat     1.998762

# %%
#Lets take a Honeydew melon as a reference fruit
melon = df.loc[df['FOODNAME'] == 'HONEYDEW MELON, WITHOUT SKIN']
#Replace all of the normalized component values in our data fram with the distance between our melon
# its component values and the given foods component values.
for header in df.head():
    if not header in ["FOODID","FOODNAME","DESCRIPT"]:
        df[header] = df[header] - melon[[header]].values[0]
# A list for holding our results.
rowlist = []
#Itterate over our dataframe
for index,row in df.iterrows():
    food = row.values[1]
    foodtype = row.values[2]
    #Determine the vector distance between the melon and this food.
    vector = row.values[3:]
    distance = np.linalg.norm(vector)/reference_vectordistance
    # Only look at MCDONALD foods and foods in the Chocolate food group
    if "MCDONALD" in food or foodtype == "Chocolate":
        row = dict()
        row["food"] = food
        row["distance"] = distance
        rowlist.append(row)

# Turn our results into a pandas dataframe
peerfood = pandas.DataFrame(rowlist)
#Display the other foods sorted by normalized vector distance.
with pandas.option_context('display.max_rows', None, 'display.max_columns', None):
    print(peerfood.sort_values(by=['distance']))
# Out:
#     distance                                               food
# 21  0.956963                     MILKSHAKE, VANILLA, MCDONALD'S
# 23  1.515775                     HAMBURGER, MCFEAST, MCDONALD'S
# 10  1.589669         HAMBURGER, BEEF AND WHEAT ROLL, MCDONALD'S
# 11  1.647408               HAMBURGER, CHEESE BURGER, MCDONALD'S
# 13  1.647526      HAMBURGER, DOUBLE BURGER, BIG MAC, MCDONALD'S
# 12  1.728808              HAMBURGER, CHICKEN BURGER, MCDONALD'S
# 22  1.986608        HAMBURGER, DOUBLE CHEESE BURGER, MCDONALD'S
# 1   2.542666         CHOCOLATE CONFECTION FILLED WITH MARMALADE
# 14  2.915553            CHOCOLATE BAR, CARAMEL AND COOKIE, TWIX
# 24  2.915631         CHOCOLATE CONFECTION FILLED WITH CHOCOLATE
# 18  2.978043  SUFFELI CHOCOLATE BAR, WAFFLE, TOFFEE FILLING ...
# 7   3.174270                             CHOCOLATE BAR, LOW-FAT
# 6   3.224222                CHOCOLATE BAR WITH FILLING, AVERAGE
# 2   3.336511                             CHOCOLATE BAR, AVERAGE
# 15  3.350807  SUFFELI PUFFI SNACKS,PUFFED CORN AND CHOCOLATE...
# 3   3.354410                   CHOCOLATE, PLAIN, DARK CHOCOLATE
# 8   3.409912                         CHOCOLATE, WHITE CHOCOLATE
# 0   3.431798                                 CHOCOLATE, AVERAGE
# 16  3.469495                               CHOCOLATE NUT SPREAD
# 20  3.509146           CHOCOLATE, MILK CHOCOLATE WITH HAZELNUTS
# 4   3.763362                          CHOCOLATE, MILK CHOCOLATE
# 17  3.789385                               KINDER CHOCOLATE EGG
# 9   3.863914                                     RICE CHOCOLATE
# 19  4.175258              CHOCOLATE, PLAIN, DARK CHOCOLATE, 80%
# 5   5.557062                  CHOCOLATE, ARTIFICIALLY SWEETENED

# %%
count1 = 0
count2 = 0
count3 = 0
tcount = 0
for index,row in df.iterrows():
    food = row.values[1]
    foodtype = row.values[2]
    vector = row.values[3:]
    distance = np.linalg.norm(vector)/reference_vectordistance
    if "Vegetables" == foodtype:
        tcount += 1
        if distance > 2.915553:
            print("+ " ,food,"is further removed, nutritionally, from a melon than a Twix bar is")
            count3 +=1
        if distance > 1.986608:
            print("- " ,food,"is further removed, nutritionally, from a melon than a double cheeseburger is")
            count2 +=1
        if distance > 0.956963:
            print("# " ,food,"is further removed, nutritionally, from a melon than a milkshake is")
            count1 +=1
print()
print("* A milkshake is nutritionally closer to a melon than", count1,"out of", tcount,"vegetables.")
print("* A double cheeseburger is nutritionally closer to a melon than", count2,"out of", tcount, "vegetables.")
print("* A Twix candy bar is nutritionally closer to a melon than", count3,"out of", tcount,"vegetables.")
# Out:
# #  CARROT is further removed, nutritionally, from a melon than a milkshake is
# +  CARROT, DRIED is further removed, nutritionally, from a melon than a Twix bar is
# -  CARROT, DRIED is further removed, nutritionally, from a melon than a double cheeseburger is
# #  CARROT, DRIED is further removed, nutritionally, from a melon than a milkshake is
# #  JERUSALEM ARTICHOKE is further removed, nutritionally, from a melon than a milkshake is
# #  BLACK SALSIFY is further removed, nutritionally, from a melon than a milkshake is
# #  CAULIFLOWER is further removed, nutritionally, from a melon than a milkshake is
# #  BROCCOLI is further removed, nutritionally, from a melon than a milkshake is
# +  KALE is further removed, nutritionally, from a melon than a Twix bar is
# -  KALE is further removed, nutritionally, from a melon than a double cheeseburger is
# #  KALE is further removed, nutritionally, from a melon than a milkshake is
# -  BRUSSELS SPROUT is further removed, nutritionally, from a melon than a double cheeseburger is
# #  BRUSSELS SPROUT is further removed, nutritionally, from a melon than a milkshake is
# #  KOHLRABI is further removed, nutritionally, from a melon than a milkshake is
# #  LETTUCE is further removed, nutritionally, from a melon than a milkshake is
# +  PARSLEY is further removed, nutritionally, from a melon than a Twix bar is
# -  PARSLEY is further removed, nutritionally, from a melon than a double cheeseburger is
# #  PARSLEY is further removed, nutritionally, from a melon than a milkshake is
# -  NETTLE, STINGING NETTLE is further removed, nutritionally, from a melon than a double cheeseburger is
# #  NETTLE, STINGING NETTLE is further removed, nutritionally, from a melon than a milkshake is
# +  ONION, DRIED is further removed, nutritionally, from a melon than a Twix bar is
# -  ONION, DRIED is further removed, nutritionally, from a melon than a double cheeseburger is
# #  ONION, DRIED is further removed, nutritionally, from a melon than a milkshake is
# #  CELERY is further removed, nutritionally, from a melon than a milkshake is
# #  PUMPKIN is further removed, nutritionally, from a melon than a milkshake is
# +  SWEET PEPPER, AVERAGE is further removed, nutritionally, from a melon than a Twix bar is
# -  SWEET PEPPER, AVERAGE is further removed, nutritionally, from a melon than a double cheeseburger is
# #  SWEET PEPPER, AVERAGE is further removed, nutritionally, from a melon than a milkshake is
# #  MIXED VEGETABLES, CARROT, CAULIFLOWER, PEA, BEAN is further removed, nutritionally, from a melon than a milkshake is
# +  SWISS CHARD is further removed, nutritionally, from a melon than a Twix bar is
# -  SWISS CHARD is further removed, nutritionally, from a melon than a double cheeseburger is
# #  SWISS CHARD is further removed, nutritionally, from a melon than a milkshake is
# #  SWEET CORN KERNELS is further removed, nutritionally, from a melon than a milkshake is
# -  GARDEN CRESS is further removed, nutritionally, from a melon than a double cheeseburger is
# #  GARDEN CRESS is further removed, nutritionally, from a melon than a milkshake is
# +  DILL, FRESH is further removed, nutritionally, from a melon than a Twix bar is
# -  DILL, FRESH is further removed, nutritionally, from a melon than a double cheeseburger is
# #  DILL, FRESH is further removed, nutritionally, from a melon than a milkshake is
# #  BEANSPROUTS AND ALFALFA SPROUTS, AVERAGE is further removed, nutritionally, from a melon than a milkshake is
# +  SWEET PEPPER, RED is further removed, nutritionally, from a melon than a Twix bar is
# -  SWEET PEPPER, RED is further removed, nutritionally, from a melon than a double cheeseburger is
# #  SWEET PEPPER, RED is further removed, nutritionally, from a melon than a milkshake is
# -  SWEET PEPPER, GREEN is further removed, nutritionally, from a melon than a double cheeseburger is
# #  SWEET PEPPER, GREEN is further removed, nutritionally, from a melon than a milkshake is
# +  SWEET PEPPER, YELLOW is further removed, nutritionally, from a melon than a Twix bar is
# -  SWEET PEPPER, YELLOW is further removed, nutritionally, from a melon than a double cheeseburger is
# #  SWEET PEPPER, YELLOW is further removed, nutritionally, from a melon than a milkshake is
# #  CHIVES is further removed, nutritionally, from a melon than a milkshake is
# -  GARLIC is further removed, nutritionally, from a melon than a double cheeseburger is
# #  GARLIC is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, PEA-SWEET CORN-SWEET PEPPER is further removed, nutritionally, from a melon than a milkshake is
# #  (ARC)LEAF VEGETABLE, AVERAGE, DARK GREEN is further removed, nutritionally, from a melon than a milkshake is
# +  BASIL, FRESH is further removed, nutritionally, from a melon than a Twix bar is
# -  BASIL, FRESH is further removed, nutritionally, from a melon than a double cheeseburger is
# #  BASIL, FRESH is further removed, nutritionally, from a melon than a milkshake is
# #  VEGETABLE MIX, CAULIFLOWER, BROCCOLI, CARROT is further removed, nutritionally, from a melon than a milkshake is
# +  HORSERADISH is further removed, nutritionally, from a melon than a Twix bar is
# -  HORSERADISH is further removed, nutritionally, from a melon than a double cheeseburger is
# #  HORSERADISH is further removed, nutritionally, from a melon than a milkshake is
# #  ASPARAGUS, RAW, CLEANED is further removed, nutritionally, from a melon than a milkshake is
# #  WOK-VEGETABLES, CARROT-CHAMPIGNON-ONION-SWEET PEPPER-PEA, FROZEN is further removed, nutritionally, from a melon than a milkshake is
# #  WOK-VEGETABLES, GREEN BEAN-CARROT-SWEET PEPPER- SWEET CORN-PARSNIP, FROZEN is further removed, nutritionally, from a melon than a milkshake is
# #  WOK-VEGETABLES, SWEET PEPPER-ONION-SWEET CORN-BEANS, FROZEN is further removed, nutritionally, from a melon than a milkshake is
# #  WOK-VEGETABLES, CORN-CARROT-PEA-BROCCOLI-SWEET PEPPER-MUSHROOM-LEEK, FROZEN is further removed, nutritionally, from a melon than a milkshake is
# -  WATER CHESTNUT is further removed, nutritionally, from a melon than a double cheeseburger is
# #  WATER CHESTNUT is further removed, nutritionally, from a melon than a milkshake is
# #  WOK-VEGETABLES, CARROT-PEA-WATER CHESTNUT-BAMBOO SHOOT-SWEET PEPPER-MUSHROOM is further removed, nutritionally, from a melon than a milkshake is
# #  SWEET POTATO, WITHOUT SKIN is further removed, nutritionally, from a melon than a milkshake is
# +  CHILI, GREEN, RAW is further removed, nutritionally, from a melon than a Twix bar is
# -  CHILI, GREEN, RAW is further removed, nutritionally, from a melon than a double cheeseburger is
# #  CHILI, GREEN, RAW is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, GRILLED VEGETABLES, SALT, OIL is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, CARROT-BEAN, AURINKOKASVIKSET is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, PEA-SWEET CORN-CARROT is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, BROCCOLI-CARROT-SWEET PEPPER, KARTANON KASVIKSET is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, BROCCOLI-CARROT-CAULIFLOWER, KRUUNUSEKOITUS is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, CARROT-PARSNIP-BEAN, MAALAISKASVIKSET is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, BROCCOLI-CARROT-WATER CHESTNUT is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, BROCCOLI-SWEET CORN-CARROT is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, CARROT-BROCCOLI-BEAN-SWEET PEPPER-SWEET CORN, AMERIKAN is further removed, nutritionally, from a melon than a milkshake is
# -  SPINACH is further removed, nutritionally, from a melon than a double cheeseburger is
# #  SPINACH is further removed, nutritionally, from a melon than a milkshake is
# #  FROZEN VEGETABLE MIX, CARROT-BEAN-BROCCOLI-CAULIFLOWER is further removed, nutritionally, from a melon than a milkshake is
# #  ROCKET, ARUGULA is further removed, nutritionally, from a melon than a milkshake is
# -  SPINACH, FROZEN is further removed, nutritionally, from a melon than a double cheeseburger is
# #  SPINACH, FROZEN is further removed, nutritionally, from a melon than a milkshake is
# #  WILD ROCKET, SAND ROCKET is further removed, nutritionally, from a melon than a milkshake is
# #  GARDEN LETTUCE is further removed, nutritionally, from a melon than a milkshake is
# #  RADICCHIO is further removed, nutritionally, from a melon than a milkshake is
# #  ROMAINE LETTUCE is further removed, nutritionally, from a melon than a milkshake is
# #  PEA SHOOT is further removed, nutritionally, from a melon than a milkshake is
# -  CORN SALAD, LAMB'S LETTUCE is further removed, nutritionally, from a melon than a double cheeseburger is
# #  CORN SALAD, LAMB'S LETTUCE is further removed, nutritionally, from a melon than a milkshake is
# -  CORIANDER, FRESH is further removed, nutritionally, from a melon than a double cheeseburger is
# #  CORIANDER, FRESH is further removed, nutritionally, from a melon than a milkshake is
# -  HERB, FRESH, AVERAGE is further removed, nutritionally, from a melon than a double cheeseburger is
# #  HERB, FRESH, AVERAGE is further removed, nutritionally, from a melon than a milkshake is
# #  SPRUCE BUD is further removed, nutritionally, from a melon than a milkshake is
# -  ROSEBAY WILLOW HERB OR FIREWEED, SHOOT is further removed, nutritionally, from a melon than a double cheeseburger is
# #  ROSEBAY WILLOW HERB OR FIREWEED, SHOOT is further removed, nutritionally, from a melon than a milkshake is
# #  DANDELION, LEAF is further removed, nutritionally, from a melon than a milkshake is
# #  DANDELION, BUD is further removed, nutritionally, from a melon than a milkshake is
# #  GOUTWEED, GROUND ELDER, HERB GERARD, LEAF is further removed, nutritionally, from a melon than a milkshake is
# +  BLACK CURRANT, LEAF is further removed, nutritionally, from a melon than a Twix bar is
# -  BLACK CURRANT, LEAF is further removed, nutritionally, from a melon than a double cheeseburger is
# #  BLACK CURRANT, LEAF is further removed, nutritionally, from a melon than a milkshake is
# #  DANDELION, BUD AND LEAF, AVERAGE is further removed, nutritionally, from a melon than a milkshake is
# -  ANGELICA is further removed, nutritionally, from a melon than a double cheeseburger is
# #  ANGELICA is further removed, nutritionally, from a melon than a milkshake is
# #  YARROW is further removed, nutritionally, from a melon than a milkshake is
#
# * A milkshake is nutritionally closer to a melon than 71 out of 103 vegetables.
# * A double cheeseburger is nutritionally closer to a melon than 26 out of 103 vegetables.
# * A Twix candy bar is nutritionally closer to a melon than 13 out of 103 vegetables.

# %%
# List of specific foods to compare to our melon in detail
compare = ['MILKSHAKE, VANILLA, MCDONALD\'S','KALE','BROCCOLI','CHOCOLATE BAR, CARAMEL AND COOKIE, TWIX']
#Subset of our data frame containing our four chosen foods.
part = df.loc[df['FOODNAME'].isin(compare)]
# Food name as dataframe axis, drop unneeded columns.
part = part.set_index('FOODNAME').drop(['FOODID','DESCRIPT'], axis=1)
# Twap the rows and columns, use shorter column names.
part = part.transpose().rename(columns={"CHOCOLATE BAR, CARAMEL AND COOKIE, TWIX": "TWIX",
                     "MILKSHAKE, VANILLA, MCDONALD'S": "MILKSHAKE"})
#Get the actual english descriptions for the components in our dataframe
names = eufdname.drop(['LANG'], axis=1).rename(columns={"THSCODE": "FOODNAME"}).set_index("FOODNAME")
#Merge the names with our transposed food subset
results = pandas.merge(how='left', right=names, left=part, left_index=True, right_index = True).set_index("DESCRIPT").round(1)
# Out:
#                                                    BROCCOLI  KALE  TWIX  \
# DESCRIPT
# energy,calculated                                      -0.0   0.0   2.9
# fat, total                                              0.0   0.0   1.6
# carbohydrate, available                                -0.3  -0.3   2.7
# protein, total                                          0.4   0.3   0.3
# alcohol                                                 0.0   0.0   0.0
# organic acids, total                                    0.1  -0.3  -0.4
# sugar alcohols                                          0.0   0.0   0.0
# sugars, total                                          -0.6  -0.6   4.2
# fructose                                               -0.3  -0.3   0.7
# galactose                                              -0.1  -0.1  -0.2
# glucose                                                -0.3  -0.3   1.1
# lactose                                                 0.0   0.0   0.5
# maltose                                                 0.1   0.1   0.5
# sucrose                                                -0.5  -0.5   4.6
# starch, total                                           0.0   0.0   0.5
# fibre, total                                            0.6   1.3   0.2
# fibre, water-insoluble                                  0.5   0.3   0.3
# polysaccharides, non-cellulosic, water-soluble          0.6   0.6   0.2
# folate, total                                           1.5   1.6   0.0
# niacin equivalents, total                               0.3   0.2   0.1
# niacin, preformed (nicotinic acid + nicotinamide)       0.2   0.3  -0.0
# vitamers pyridoxine (hydrochloride)                     0.2   1.3  -0.1
# riboflavine                                             0.7   1.2   0.2
# thiamin (vitamin B1)                                    0.4   0.5  -0.1
# vitamin A  retinol activity equivalents                 0.1   0.7   0.0
# carotenoids, total                                      1.1  16.5  -0.0
# vitamin B-12 (cobalamin)                                0.0   0.0   0.0
# vitamin C (ascorbic acid)                               3.0   3.0  -0.5
# vitamin D                                               0.0   0.0   0.0
# vitamin E  alphatocopherol                              0.2   2.0   0.4
# vitamin K, total                                        2.2  12.5   0.0
# calcium                                                 0.1   1.1   0.1
# iron, total                                             0.2   0.2   0.2
# iodide (iodine)                                        -0.0  -0.0  -0.0
# potassium                                               0.5   0.7  -0.1
# magnesium                                               0.2   0.4   0.3
# salt                                                   -0.0  -0.0   0.1
# phosphorus                                              0.4   0.2   0.2
# selenium, total                                         0.2   0.2   0.0
# zinc                                                    0.4   0.2   0.3
# fatty acids, total                                      0.0   0.0   1.6
# fatty acids, total polyunsaturated                      0.0   0.1   0.4
# fatty acids, total monounsaturated cis                  0.0   0.0   1.3
# fatty acids, total saturated                            0.0   0.0   2.1
# fatty acids, total trans                                0.0   0.0   0.2
# fatty acids, total n-3 polyunsaturated                  0.1   0.2   0.0
# fatty acids, total n-6 polyunsaturated                  0.0   0.0   0.5
# fatty acid 18:2 cis,cis n-6 (linoleic acid)             0.0   0.0   0.6
# fatty acid 18:3 n-3 (alpha-linolenic acid)              0.1   0.3   0.0
# fatty acid 20:5 n-3 (EPA)                               0.0   0.0   0.0
# fatty acid 22:6 n-3 (DHA)                               0.0   0.0   0.0
# cholesterol (GC)                                        0.0   0.0   0.1
# sterols, total                                          0.2   0.0   0.2
# tryptophan                                              0.3   0.8   0.3
#
#                                                    MILKSHAKE
# DESCRIPT
# energy,calculated                                        0.3
# fat, total                                               0.1
# carbohydrate, available                                  0.2
# protein, total                                           0.3
# alcohol                                                  0.0
# organic acids, total                                    -0.1
# sugar alcohols                                           0.0
# sugars, total                                            0.4
# fructose                                                -0.5
# galactose                                                2.3
# glucose                                                  0.3
# lactose                                                  0.6
# maltose                                                  0.0
# sucrose                                                  0.1
# starch, total                                            0.0
# fibre, total                                            -0.2
# fibre, water-insoluble                                  -0.2
# polysaccharides, non-cellulosic, water-soluble          -0.2
# folate, total                                            0.0
# niacin equivalents, total                                0.1
# niacin, preformed (nicotinic acid + nicotinamide)       -0.1
# vitamers pyridoxine (hydrochloride)                     -0.0
# riboflavine                                              0.6
# thiamin (vitamin B1)                                     0.0
# vitamin A  retinol activity equivalents                  0.0
# carotenoids, total                                      -0.0
# vitamin B-12 (cobalamin)                                 0.1
# vitamin C (ascorbic acid)                               -0.4
# vitamin D                                                0.0
# vitamin E  alphatocopherol                               0.0
# vitamin K, total                                         0.0
# calcium                                                  0.5
# iron, total                                             -0.0
# iodide (iodine)                                         -0.0
# potassium                                               -0.1
# magnesium                                                0.0
# salt                                                     0.0
# phosphorus                                               0.4
# selenium, total                                          0.0
# zinc                                                     0.3
# fatty acids, total                                       0.1
# fatty acids, total polyunsaturated                      -0.0
# fatty acids, total monounsaturated cis                   0.1
# fatty acids, total saturated                             0.2
# fatty acids, total trans                                 0.1
# fatty acids, total n-3 polyunsaturated                  -0.0
# fatty acids, total n-6 polyunsaturated                   0.0
# fatty acid 18:2 cis,cis n-6 (linoleic acid)              0.0
# fatty acid 18:3 n-3 (alpha-linolenic acid)              -0.0
# fatty acid 20:5 n-3 (EPA)                                0.0
# fatty acid 22:6 n-3 (DHA)                                0.0
# cholesterol (GC)                                         0.1
# sterols, total                                          -0.0
# tryptophan                                               0.3
